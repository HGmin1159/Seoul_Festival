# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
a = pd.read_excel("festival_info_1516_transform_coord.xlsx")

# %%
a.head()
# Out:
#         축제명_수정        시작일        종료일       축제장소_수정  \
# 0  서울국제빵과자페스티벌 2015-11-18 2015-11-21           코엑스
# 1    아르헨티나페스티발 2015-09-05 2015-09-05    대학로 마로니에공원
# 2         한강홀릭 2015-09-19 2015-09-19        반포한강공원
# 3   그랜드케이팝페스티벌 2015-09-04 2015-09-04  잠실 올림픽 주 경기장
# 4      서리풀페스티벌 2015-09-15 2015-09-20        예술의 전당
#
#                                              축제설명_수정  \
# 0  2015년 11월 18일부터 21일까지 코엑스에서 <서울국제빵과자페스티벌>이 열린다...
# 1  사단법인 한국아르헨티나협회와 주한 아르헨티나 대사관은 한인 이민 50주년을 기념하기...
# 2  한강을 그리다! 한강에 열광하다!\r한강에 홀딱 빠져드는 이색축제,\rHangang...
# 3  대한민국의 최정상급 케이팝 스타들이 대거 출연하는 케이팝 한류 페스티벌이 9월4일 ...
# 4  서리풀페스티벌은 서초구의 고품격 예술자원과 글로벌 문화콘텐츠를 결집한 축제로 K-컬...
#
#                              관련 누리집  \
# 0              http://siba-expo.com
# 1                               NaN
# 2      http://www.hangangholic.com/
# 3  http://www.grandkpopfestival.com
# 4  http://blog.naver.com/sccf150508
#
#                                        문의_수정  \
# 0                        (주)코엑스 02-6000-8164
# ...

# %%
a['축제일수'].value_counts()
# Out:
# 1    29
# 2    24
# 3    13
# 4     5
# 6     2
# 5     2
# 7     1
# Name: 축제일수, dtype: int64

# %% [markdown]
# # 시작일자 = 분석일자
#
# - 분석의 용이성을 위해 기간을 하루로 특정
# - 보통 축제 개최일에 가장 많은 사람이 오기때문에 시작일자를 분석일자로 정함

# %% [markdown]
# ## 개최년월

# %%
a['개최년월'] = a['시작일'].dt.strftime('%Y%m')

# %% [markdown]
# ## 비교일자 추출
#
# - 동년동기 : -14일, +14일 기간 중 같은 요일

# %%
from datetime import datetime, timedelta

a['wk_1_before'] = a['시작일'] - timedelta(days=7)
a['wk_2_before'] = a['시작일'] - timedelta(days=14)

a['wk_1_after'] = a['시작일'] + timedelta(days=7)
a['wk_2_after'] = a['시작일'] + timedelta(days=14)

# %%
a['분석일'] = a['시작일'].dt.strftime('%Y%m%d')
a['wk_1_before'] = a['wk_1_before'].dt.strftime('%Y%m%d')
a['wk_2_before'] = a['wk_2_before'].dt.strftime('%Y%m%d')
a['wk_1_after'] = a['wk_1_after'].dt.strftime('%Y%m%d')
a['wk_2_after'] = a['wk_2_after'].dt.strftime('%Y%m%d')

# %%
a
# Out:
#                    축제명_수정        시작일        종료일             축제장소_수정  \
# 0             서울국제빵과자페스티벌 2015-11-18 2015-11-21                 코엑스
# 1               아르헨티나페스티발 2015-09-05 2015-09-05          대학로 마로니에공원
# 2                    한강홀릭 2015-09-19 2015-09-19              반포한강공원
# 3              그랜드케이팝페스티벌 2015-09-04 2015-09-04        잠실 올림픽 주 경기장
# 4                 서리풀페스티벌 2015-09-15 2015-09-20              예술의 전당
# ..                    ...        ...        ...                 ...
# 71             세종탄신기념문화행사 2016-05-15 2016-05-15             국립한글박물관
# 72             희망의운동화나눔축제 2016-05-20 2016-05-21           서울 광화문 광장
# 73                   빗물축제 2016-07-28 2016-07-31             서울시청 광장
# 74  남산골한옥마을세시맞이오(五)대감설날잔치 2016-02-08 2016-02-09  서울특별시 중구 퇴계로34길 28
# 75                   종묘대제 2016-05-01 2016-05-01           서울 종로구 종묘
#
#                                               축제설명_수정  \
# 0   2015년 11월 18일부터 21일까지 코엑스에서 <서울국제빵과자페스티벌>이 열린다...
# ...

# %%
a = a.sort_values('분석일')

# %%
a = a.reset_index(drop=True).reset_index().rename(columns={'index':'축제번호'})
a['축제번호'] = a['축제번호']+1

# %%
a
# Out:
#     축제번호                  축제명_수정        시작일        종료일         축제장소_수정  \
# 0      1                서울드럼페스티벌 2015-08-07 2015-08-08          서울시청광장
# 1      2              그랜드케이팝페스티벌 2015-09-04 2015-09-04    잠실 올림픽 주 경기장
# 2      3               북팔코믹스페스티벌 2015-09-05 2015-09-06          노들나루공원
# 3      4               아르헨티나페스티발 2015-09-05 2015-09-05      대학로 마로니에공원
# 4      5             강동친환경도시농업축제 2015-09-05 2015-09-05            강동구청
# ..   ...                     ...        ...        ...             ...
# 71    72  땡큐페스티벌(ThankUFestival) 2016-06-18 2016-06-18          상암 MBC
# 72    73        연예인과함께하는희망나눔페스티벌 2016-07-01 2016-07-03           SETEC
# 73    74          10초국제애니메이션페스티벌 2016-07-14 2016-07-17         탈영역 우정국
# 74    75                 한강물싸움축제 2016-07-23 2016-07-24  여의도 한강공원 멀티플라자
# 75    76                    빗물축제 2016-07-28 2016-07-31         서울시청 광장
#
#                                               축제설명_수정  \
# 0   * 국내외 유명 타악 아티스트 초청공연\r  - 국내 : 드럼캣, 발광, 손스타, ...
# ...

# %%
a.to_excel('festival_info_1516_for_query.xlsx', encoding='cp949', index=False, float_format="%.14f")

# %% [markdown]
# # 유동인구 데이터 추출하는 쿼리 작성

# %%
a = pd.read_excel("festival_info_1516_for_query.xlsx")

# %% [markdown]
# ## 비교일자가 201508 ~ 201607인 축제만
#
# - 유동인구 데이터 기간이 201508 ~ 201607

# %%
a2 = a.loc[(a['wk_2_before']>=20150801)&(a['wk_2_after']<=20160731)]

# %%
a2 = a2.drop(['축제번호'], 1).reset_index(drop=True).reset_index().rename(columns={'index':'축제번호'})
a2['축제번호'] = a2['축제번호']+1

# %%
a2['비교년월_전_1'] = pd.to_datetime(a2['wk_1_before'], format='%Y%m%d').dt.strftime('%Y%m')
a2['비교년월_전_2'] = pd.to_datetime(a2['wk_2_before'], format='%Y%m%d').dt.strftime('%Y%m')

a2['비교년월_후_1'] = pd.to_datetime(a2['wk_1_after'], format='%Y%m%d').dt.strftime('%Y%m')
a2['비교년월_후_2'] = pd.to_datetime(a2['wk_1_after'], format='%Y%m%d').dt.strftime('%Y%m')

# %%
a2
# Out:
#     축제번호                  축제명_수정        시작일        종료일       축제장소_수정  \
# 0      1              그랜드케이팝페스티벌 2015-09-04 2015-09-04  잠실 올림픽 주 경기장
# 1      2               북팔코믹스페스티벌 2015-09-05 2015-09-06        노들나루공원
# 2      3               아르헨티나페스티발 2015-09-05 2015-09-05    대학로 마로니에공원
# 3      4             강동친환경도시농업축제 2015-09-05 2015-09-05          강동구청
# 4      5                 서리풀페스티벌 2015-09-15 2015-09-20        예술의 전당
# ..   ...                     ...        ...        ...           ...
# 68    69            한부모가족모두하나대축제 2016-06-18 2016-06-18        서울시청광장
# 69    70                불꽃곰신페스티벌 2016-06-18 2016-06-18        대현문화공원
# 70    71  땡큐페스티벌(ThankUFestival) 2016-06-18 2016-06-18        상암 MBC
# 71    72        연예인과함께하는희망나눔페스티벌 2016-07-01 2016-07-03         SETEC
# 72    73          10초국제애니메이션페스티벌 2016-07-14 2016-07-17       탈영역 우정국
#
#                                               축제설명_수정  \
# 0   대한민국의 최정상급 케이팝 스타들이 대거 출연하는 케이팝 한류 페스티벌이 9월4일 ...
# ...

# %% [markdown]
# ## 비교일자 (1주전)

# %%
f = open("query_wk_1_before.txt", 'w')
count = 1
for ym in a2['비교년월_전_1'].unique():
    print(ym)
    
    tmp = a2.loc[a2['비교년월_전_1'] == ym]
       
    for i in zip(tmp['축제번호'], tmp['wk_1_before'], tmp['x_5179'], tmp['y_5179']):
        print(i)
        f.write("SELECT STD_YM, STD_YMD,\n")
        f.write("\t '{}' as festival_no, \n".format(i[0]))
        f.write("\t MAN_FLOW_POP_CNT_0004G + MAN_FLOW_POP_CNT_0509G + MAN_FLOW_POP_CNT_1014G + MAN_FLOW_POP_CNT_1519G as MAN_10,\n")
        f.write("\t MAN_FLOW_POP_CNT_2024G + MAN_FLOW_POP_CNT_2529G as MAN_20,\n")
        f.write("\t MAN_FLOW_POP_CNT_3034G + MAN_FLOW_POP_CNT_3539G as MAN_30,\n")
        f.write("\t MAN_FLOW_POP_CNT_4044G + MAN_FLOW_POP_CNT_4549G as MAN_40,\n")
        f.write("\t MAN_FLOW_POP_CNT_5054G + MAN_FLOW_POP_CNT_5559G as MAN_50,\n")
        f.write("\t MAN_FLOW_POP_CNT_6064G + MAN_FLOW_POP_CNT_6569G + MAN_FLOW_POP_CNT_70GU) as MAN_60,\n")
        f.write("\t WMAN_FLOW_POP_CNT_0004G + WMAN_FLOW_POP_CNT_0509G + WMAN_FLOW_POP_CNT_1014G + WMAN_FLOW_POP_CNT_1519G as WMAN_10,\n")
        f.write("\t WMAN_FLOW_POP_CNT_2024G + WMAN_FLOW_POP_CNT_2529G as WMAN_20,\n")
        f.write("\t WMAN_FLOW_POP_CNT_3034G + WMAN_FLOW_POP_CNT_3539G as WMAN_30,\n")
        f.write("\t WMAN_FLOW_POP_CNT_4044G + WMAN_FLOW_POP_CNT_4549G as WMAN_40,\n")
        f.write("\t WMAN_FLOW_POP_CNT_5054G + WMAN_FLOW_POP_CNT_5559G as WMAN_50,\n")
        f.write("\t WMAN_FLOW_POP_CNT_6064G + WMAN_FLOW_POP_CNT_6570G + WMAN_FLOW_POP_CNT_70GU) as WMAN_60\n")
        
        f.write("FROM TBDW_FLPOP_INFLOW_AGE_DAY_{}\n".format(ym))
        
        f.write("WHERE STD_YMD = '{}' \n".format(i[1]))
        f.write("\t AND (X_COORD >= {} AND X_COORD <= {}  \n".format(i[2]-500, i[2]+500))
        f.write("\t AND Y_COORD >= {}  AND Y_COORD <= {} )\n".format(i[3]-500, i[3]+500))
        f.write("GROUP BY STD_YM, STD_YMD, festival_no \n")
        
        if count == 73:  
            continue
        else:
            f.write("UNION ALL \n")
        count += 1

f.write(";")
f.close()
# Out:
# 201508
# (1, 20150828, 962266.8898184684, 1946230.663872432)
# (2, 20150829, 951713.7005969977, 1946188.782141991)
# (3, 20150829, 956101.6844741853, 1953549.988175246)
# (4, 20150829, 966555.6883867003, 1947996.82343784)
# 201509
# (5, 20150908, 956997.4269698508, 1942355.685343204)
# (6, 20150908, 954569.1962608458, 1953053.726387538)
# (7, 20150912, 954789.2246593111, 1945253.569596834)
# (8, 20150920, 955376.7565971893, 1951222.289198561)
# (9, 20150924, 949315.4522236553, 1950268.48381501)
# (10, 20150925, 955950.587311305, 1953934.653370677)
# (11, 20150925, 955376.7565971893, 1951222.289198561)
# 201510
# (12, 20151002, 954136.361299988, 1947003.20955536)
# (13, 20151003, 942800.4927573171, 1952288.844565486)
# (14, 20151016, 953278.4964771426, 1952158.719084875)
# (15, 20151018, 949462.3606815953, 1948268.412266112)
# (16, 20151022, 953278.4964771426, 1952158.719084875)
# (17, 20151022, 953278.4964771426, 1952158.719084875)
# ...

# %% [markdown]
# ## 비교일자 (2주전)

# %%
f = open("query_wk_2_before.txt", 'w')
count = 1
for ym in a2['비교년월_전_2'].unique():
    print(ym)
    
    tmp = a2.loc[a2['비교년월_전_2'] == ym]
       
    for i in zip(tmp['축제번호'], tmp['wk_2_before'], tmp['x_5179'], tmp['y_5179']):
        print(i)
        f.write("SELECT STD_YM, STD_YMD,\n")
        f.write("\t '{}' as festival_no, \n".format(i[0]))
        f.write("\t MAN_FLOW_POP_CNT_0004G + MAN_FLOW_POP_CNT_0509G + MAN_FLOW_POP_CNT_1014G + MAN_FLOW_POP_CNT_1519G as MAN_10,\n")
        f.write("\t MAN_FLOW_POP_CNT_2024G + MAN_FLOW_POP_CNT_2529G as MAN_20,\n")
        f.write("\t MAN_FLOW_POP_CNT_3034G + MAN_FLOW_POP_CNT_3539G as MAN_30,\n")
        f.write("\t MAN_FLOW_POP_CNT_4044G + MAN_FLOW_POP_CNT_4549G as MAN_40,\n")
        f.write("\t MAN_FLOW_POP_CNT_5054G + MAN_FLOW_POP_CNT_5559G as MAN_50,\n")
        f.write("\t MAN_FLOW_POP_CNT_6064G + MAN_FLOW_POP_CNT_6569G + MAN_FLOW_POP_CNT_70GU) as MAN_60,\n")
        f.write("\t WMAN_FLOW_POP_CNT_0004G + WMAN_FLOW_POP_CNT_0509G + WMAN_FLOW_POP_CNT_1014G + WMAN_FLOW_POP_CNT_1519G as WMAN_10,\n")
        f.write("\t WMAN_FLOW_POP_CNT_2024G + WMAN_FLOW_POP_CNT_2529G as WMAN_20,\n")
        f.write("\t WMAN_FLOW_POP_CNT_3034G + WMAN_FLOW_POP_CNT_3539G as WMAN_30,\n")
        f.write("\t WMAN_FLOW_POP_CNT_4044G + WMAN_FLOW_POP_CNT_4549G as WMAN_40,\n")
        f.write("\t WMAN_FLOW_POP_CNT_5054G + WMAN_FLOW_POP_CNT_5559G as WMAN_50,\n")
        f.write("\t WMAN_FLOW_POP_CNT_6064G + WMAN_FLOW_POP_CNT_6570G + WMAN_FLOW_POP_CNT_70GU) as WMAN_60\n")
        
        f.write("FROM TBDW_FLPOP_INFLOW_AGE_DAY_{}\n".format(ym))
        
        f.write("WHERE STD_YMD = '{}' \n".format(i[1]))
        f.write("\t AND (X_COORD >= {} AND X_COORD <= {}  \n".format(i[2]-500, i[2]+500))
        f.write("\t AND Y_COORD >= {}  AND Y_COORD <= {} )\n".format(i[3]-500, i[3]+500))
        f.write("GROUP BY STD_YM, STD_YMD, festival_no \n")
        
        if count == 73:  
            continue
        else:
            f.write("UNION ALL \n")
        count += 1

f.write(";")
f.close()
# Out:
# 201508
# (1, 20150821, 962266.8898184684, 1946230.663872432)
# (2, 20150822, 951713.7005969977, 1946188.782141991)
# (3, 20150822, 956101.6844741853, 1953549.988175246)
# (4, 20150822, 966555.6883867003, 1947996.82343784)
# 201509
# (5, 20150901, 956997.4269698508, 1942355.685343204)
# (6, 20150901, 954569.1962608458, 1953053.726387538)
# (7, 20150905, 954789.2246593111, 1945253.569596834)
# (8, 20150913, 955376.7565971893, 1951222.289198561)
# (9, 20150917, 949315.4522236553, 1950268.48381501)
# (10, 20150918, 955950.587311305, 1953934.653370677)
# (11, 20150918, 955376.7565971893, 1951222.289198561)
# (12, 20150925, 954136.361299988, 1947003.20955536)
# (13, 20150926, 942800.4927573171, 1952288.844565486)
# 201510
# (14, 20151009, 953278.4964771426, 1952158.719084875)
# (15, 20151011, 949462.3606815953, 1948268.412266112)
# (16, 20151015, 953278.4964771426, 1952158.719084875)
# (17, 20151015, 953278.4964771426, 1952158.719084875)
# ...

# %% [markdown]
# ## 비교일자 (1주후)

# %%
f = open("query_wk_1_after.txt", 'w')
count = 1
for ym in a2['비교년월_후_1'].unique():
    print(ym)
    
    tmp = a2.loc[a2['비교년월_후_1'] == ym]
       
    for i in zip(tmp['축제번호'], tmp['wk_1_after'], tmp['x_5179'], tmp['y_5179']):
        print(i)
        f.write("SELECT STD_YM, STD_YMD,\n")
        f.write("\t '{}' as festival_no, \n".format(i[0]))
        f.write("\t MAN_FLOW_POP_CNT_0004G + MAN_FLOW_POP_CNT_0509G + MAN_FLOW_POP_CNT_1014G + MAN_FLOW_POP_CNT_1519G as MAN_10,\n")
        f.write("\t MAN_FLOW_POP_CNT_2024G + MAN_FLOW_POP_CNT_2529G as MAN_20,\n")
        f.write("\t MAN_FLOW_POP_CNT_3034G + MAN_FLOW_POP_CNT_3539G as MAN_30,\n")
        f.write("\t MAN_FLOW_POP_CNT_4044G + MAN_FLOW_POP_CNT_4549G as MAN_40,\n")
        f.write("\t MAN_FLOW_POP_CNT_5054G + MAN_FLOW_POP_CNT_5559G as MAN_50,\n")
        f.write("\t MAN_FLOW_POP_CNT_6064G + MAN_FLOW_POP_CNT_6569G + MAN_FLOW_POP_CNT_70GU) as MAN_60,\n")
        f.write("\t WMAN_FLOW_POP_CNT_0004G + WMAN_FLOW_POP_CNT_0509G + WMAN_FLOW_POP_CNT_1014G + WMAN_FLOW_POP_CNT_1519G as WMAN_10,\n")
        f.write("\t WMAN_FLOW_POP_CNT_2024G + WMAN_FLOW_POP_CNT_2529G as WMAN_20,\n")
        f.write("\t WMAN_FLOW_POP_CNT_3034G + WMAN_FLOW_POP_CNT_3539G as WMAN_30,\n")
        f.write("\t WMAN_FLOW_POP_CNT_4044G + WMAN_FLOW_POP_CNT_4549G as WMAN_40,\n")
        f.write("\t WMAN_FLOW_POP_CNT_5054G + WMAN_FLOW_POP_CNT_5559G as WMAN_50,\n")
        f.write("\t WMAN_FLOW_POP_CNT_6064G + WMAN_FLOW_POP_CNT_6570G + WMAN_FLOW_POP_CNT_70GU) as WMAN_60\n")
        
        f.write("FROM TBDW_FLPOP_INFLOW_AGE_DAY_{}\n".format(ym))
        
        f.write("WHERE STD_YMD = '{}' \n".format(i[1]))
        f.write("\t AND (X_COORD >= {} AND X_COORD <= {}  \n".format(i[2]-500, i[2]+500))
        f.write("\t AND Y_COORD >= {}  AND Y_COORD <= {} )\n".format(i[3]-500, i[3]+500))
        f.write("GROUP BY STD_YM, STD_YMD, festival_no \n")
        
        if count == 73:  
            continue
        else:
            f.write("UNION ALL \n")
        count += 1

f.write(";")
f.close()
# Out:
# 201509
# (1, 20150911, 962266.8898184684, 1946230.663872432)
# (2, 20150912, 951713.7005969977, 1946188.782141991)
# (3, 20150912, 956101.6844741853, 1953549.988175246)
# (4, 20150912, 966555.6883867003, 1947996.82343784)
# (5, 20150922, 956997.4269698508, 1942355.685343204)
# (6, 20150922, 954569.1962608458, 1953053.726387538)
# (7, 20150926, 954789.2246593111, 1945253.569596834)
# 201510
# (8, 20151004, 955376.7565971893, 1951222.289198561)
# (9, 20151008, 949315.4522236553, 1950268.48381501)
# (10, 20151009, 955950.587311305, 1953934.653370677)
# (11, 20151009, 955376.7565971893, 1951222.289198561)
# (12, 20151016, 954136.361299988, 1947003.20955536)
# (13, 20151017, 942800.4927573171, 1952288.844565486)
# (14, 20151030, 953278.4964771426, 1952158.719084875)
# 201511
# (15, 20151101, 949462.3606815953, 1948268.412266112)
# (16, 20151105, 953278.4964771426, 1952158.719084875)
# (17, 20151105, 953278.4964771426, 1952158.719084875)
# ...

# %% [markdown]
# ## 비교일자 (2주후)

# %%
f = open("query_wk_2_after.txt", 'w')
count = 1
for ym in a2['비교년월_후_2'].unique():
    print(ym)
    
    tmp = a2.loc[a2['비교년월_후_2'] == ym]
       
    for i in zip(tmp['축제번호'], tmp['wk_2_after'], tmp['x_5179'], tmp['y_5179']):
        print(i)
        f.write("SELECT STD_YM, STD_YMD,\n")
        f.write("\t '{}' as festival_no, \n".format(i[0]))
        f.write("\t MAN_FLOW_POP_CNT_0004G + MAN_FLOW_POP_CNT_0509G + MAN_FLOW_POP_CNT_1014G + MAN_FLOW_POP_CNT_1519G as MAN_10,\n")
        f.write("\t MAN_FLOW_POP_CNT_2024G + MAN_FLOW_POP_CNT_2529G as MAN_20,\n")
        f.write("\t MAN_FLOW_POP_CNT_3034G + MAN_FLOW_POP_CNT_3539G as MAN_30,\n")
        f.write("\t MAN_FLOW_POP_CNT_4044G + MAN_FLOW_POP_CNT_4549G as MAN_40,\n")
        f.write("\t MAN_FLOW_POP_CNT_5054G + MAN_FLOW_POP_CNT_5559G as MAN_50,\n")
        f.write("\t MAN_FLOW_POP_CNT_6064G + MAN_FLOW_POP_CNT_6569G + MAN_FLOW_POP_CNT_70GU) as MAN_60,\n")
        f.write("\t WMAN_FLOW_POP_CNT_0004G + WMAN_FLOW_POP_CNT_0509G + WMAN_FLOW_POP_CNT_1014G + WMAN_FLOW_POP_CNT_1519G as WMAN_10,\n")
        f.write("\t WMAN_FLOW_POP_CNT_2024G + WMAN_FLOW_POP_CNT_2529G as WMAN_20,\n")
        f.write("\t WMAN_FLOW_POP_CNT_3034G + WMAN_FLOW_POP_CNT_3539G as WMAN_30,\n")
        f.write("\t WMAN_FLOW_POP_CNT_4044G + WMAN_FLOW_POP_CNT_4549G as WMAN_40,\n")
        f.write("\t WMAN_FLOW_POP_CNT_5054G + WMAN_FLOW_POP_CNT_5559G as WMAN_50,\n")
        f.write("\t WMAN_FLOW_POP_CNT_6064G + WMAN_FLOW_POP_CNT_6570G + WMAN_FLOW_POP_CNT_70GU) as WMAN_60\n")
        
        f.write("FROM TBDW_FLPOP_INFLOW_AGE_DAY_{}\n".format(ym))
        
        f.write("WHERE STD_YMD = '{}' \n".format(i[1]))
        f.write("\t AND (X_COORD >= {} AND X_COORD <= {}  \n".format(i[2]-500, i[2]+500))
        f.write("\t AND Y_COORD >= {}  AND Y_COORD <= {} )\n".format(i[3]-500, i[3]+500))
        f.write("GROUP BY STD_YM, STD_YMD, festival_no \n")
        
        if count == 73:  
            continue
        else:
            f.write("UNION ALL \n")
        count += 1

f.write(";")
f.close()
# Out:
# 201509
# (1, 20150918, 962266.8898184684, 1946230.663872432)
# (2, 20150919, 951713.7005969977, 1946188.782141991)
# (3, 20150919, 956101.6844741853, 1953549.988175246)
# (4, 20150919, 966555.6883867003, 1947996.82343784)
# (5, 20150929, 956997.4269698508, 1942355.685343204)
# (6, 20150929, 954569.1962608458, 1953053.726387538)
# (7, 20151003, 954789.2246593111, 1945253.569596834)
# 201510
# (8, 20151011, 955376.7565971893, 1951222.289198561)
# (9, 20151015, 949315.4522236553, 1950268.48381501)
# (10, 20151016, 955950.587311305, 1953934.653370677)
# (11, 20151016, 955376.7565971893, 1951222.289198561)
# (12, 20151023, 954136.361299988, 1947003.20955536)
# (13, 20151024, 942800.4927573171, 1952288.844565486)
# (14, 20151106, 953278.4964771426, 1952158.719084875)
# 201511
# (15, 20151108, 949462.3606815953, 1948268.412266112)
# (16, 20151112, 953278.4964771426, 1952158.719084875)
# (17, 20151112, 953278.4964771426, 1952158.719084875)
# ...

# %% [markdown]
# ## 분석일

# %%
f = open("query_the_day.txt", 'w')
count = 1
for ym in a2['개최년월'].unique():
    print(ym)
    
    tmp = a2.loc[a2['개최년월'] == ym]
       
    for i in zip(tmp['축제번호'], tmp['분석일'], tmp['x_5179'], tmp['y_5179']):
        print(i)
        f.write("SELECT STD_YM, STD_YMD,\n")
        f.write("\t '{}' as festival_no, \n".format(i[0]))
        f.write("\t MAN_FLOW_POP_CNT_0004G + MAN_FLOW_POP_CNT_0509G + MAN_FLOW_POP_CNT_1014G + MAN_FLOW_POP_CNT_1519G as MAN_10,\n")
        f.write("\t MAN_FLOW_POP_CNT_2024G + MAN_FLOW_POP_CNT_2529G as MAN_20,\n")
        f.write("\t MAN_FLOW_POP_CNT_3034G + MAN_FLOW_POP_CNT_3539G as MAN_30,\n")
        f.write("\t MAN_FLOW_POP_CNT_4044G + MAN_FLOW_POP_CNT_4549G as MAN_40,\n")
        f.write("\t MAN_FLOW_POP_CNT_5054G + MAN_FLOW_POP_CNT_5559G as MAN_50,\n")
        f.write("\t MAN_FLOW_POP_CNT_6064G + MAN_FLOW_POP_CNT_6569G + MAN_FLOW_POP_CNT_70GU) as MAN_60,\n")
        f.write("\t WMAN_FLOW_POP_CNT_0004G + WMAN_FLOW_POP_CNT_0509G + WMAN_FLOW_POP_CNT_1014G + WMAN_FLOW_POP_CNT_1519G as WMAN_10,\n")
        f.write("\t WMAN_FLOW_POP_CNT_2024G + WMAN_FLOW_POP_CNT_2529G as WMAN_20,\n")
        f.write("\t WMAN_FLOW_POP_CNT_3034G + WMAN_FLOW_POP_CNT_3539G as WMAN_30,\n")
        f.write("\t WMAN_FLOW_POP_CNT_4044G + WMAN_FLOW_POP_CNT_4549G as WMAN_40,\n")
        f.write("\t WMAN_FLOW_POP_CNT_5054G + WMAN_FLOW_POP_CNT_5559G as WMAN_50,\n")
        f.write("\t WMAN_FLOW_POP_CNT_6064G + WMAN_FLOW_POP_CNT_6570G + WMAN_FLOW_POP_CNT_70GU) as WMAN_60\n")
        
        f.write("FROM TBDW_FLPOP_INFLOW_AGE_DAY_{}\n".format(ym))
        
        f.write("WHERE STD_YMD = '{}' \n".format(i[1]))
        f.write("\t AND (X_COORD >= {} AND X_COORD <= {}  \n".format(i[2]-500, i[2]+500))
        f.write("\t AND Y_COORD >= {}  AND Y_COORD <= {} )\n".format(i[3]-500, i[3]+500))
        f.write("GROUP BY STD_YM, STD_YMD, festival_no \n")
        
        if count == 73:  
            continue
        else:
            f.write("UNION ALL \n")
        count += 1

f.write(";")
f.close()
# Out:
# 201509
# (1, 20150904, 962266.8898184684, 1946230.663872432)
# (2, 20150905, 951713.7005969977, 1946188.782141991)
# (3, 20150905, 956101.6844741853, 1953549.988175246)
# (4, 20150905, 966555.6883867003, 1947996.82343784)
# (5, 20150915, 956997.4269698508, 1942355.685343204)
# (6, 20150915, 954569.1962608458, 1953053.726387538)
# (7, 20150919, 954789.2246593111, 1945253.569596834)
# (8, 20150927, 955376.7565971893, 1951222.289198561)
# 201510
# (9, 20151001, 949315.4522236553, 1950268.48381501)
# (10, 20151002, 955950.587311305, 1953934.653370677)
# (11, 20151002, 955376.7565971893, 1951222.289198561)
# (12, 20151009, 954136.361299988, 1947003.20955536)
# (13, 20151010, 942800.4927573171, 1952288.844565486)
# (14, 20151023, 953278.4964771426, 1952158.719084875)
# (15, 20151025, 949462.3606815953, 1948268.412266112)
# (16, 20151029, 953278.4964771426, 1952158.719084875)
# (17, 20151029, 953278.4964771426, 1952158.719084875)
# (18, 20151031, 953866.7324568093, 1952317.930808754)
# ...

# %%
a2.to_excel('festival_info_1516_completed.xlsx', encoding='cp949', index=False)
